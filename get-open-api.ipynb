# %%
from api import app
import json

# %%
openapi_schema = app.openapi()
print( json.dumps(openapi_schema, indent=2) )
# Out:
# {
#   "openapi": "3.1.0",
#   "info": {
#     "title": "FastAPI",
#     "version": "0.1.0"
#   },
#   "paths": {
#     "/posts/": {
#       "get": {
#         "summary": "Get Posts",
#         "operationId": "get_posts_posts__get",
#         "parameters": [
#           {
#             "name": "skip",
#             "in": "query",
#             "required": false,
#             "schema": {
#               "type": "integer",
#               "default": 0,
#               "title": "Skip"
#             }
#           },
#           {
#             "name": "limit",
#             "in": "query",
#             "required": false,
#             "schema": {
#               "type": "integer",
#               "default": 10,
#               "title": "Limit"
#             }
#           },
#           {
#             "name": "sort",
#             "in": "query",
#             "required": false,
#             "schema": {
#               "anyOf": [
#                 {
#                   "type": "string"
# ...
